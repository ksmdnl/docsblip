# %%
import json

# %%
path = "C:/Users/DKusuma/projects/research/docsblip/data/spdocvqa_qas/test_v1.0.json"
with open(path, 'r') as f:
    data = json.load(f)

# %%
data.keys()
# Out:
# dict_keys(['dataset_name', 'dataset_version', 'dataset_split', 'data'])

# %%
data['data'][0].keys()
# Out:
# dict_keys(['questionId', 'question', 'image', 'docId', 'ucsf_document_id', 'ucsf_document_page_no', 'data_split'])

# %%
data['data'][0]['image']
# Out:
# 'documents/rnbx0223_193.png'
