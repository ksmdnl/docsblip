# %%
import json

# %%
path = "C:/Users/DKusuma/projects/research/docsblip/data/spdocvqa_qas/train_v1.0_withQT.json"
with open(path, 'r') as f:
    data = json.load(f)

# %%
len(data['data'])
# Out:
# 39463

# %%
data.keys()
# Out:
# dict_keys(['dataset_name', 'dataset_version', 'dataset_split', 'data'])

# %%
data['data'][0]
# Out:
# {'questionId': 337,
#  'question': 'what is the date mentioned in this letter?',
#  'question_types': ['handwritten', 'form'],
#  'image': 'documents/xnbl0037_1.png',
#  'docId': 279,
#  'ucsf_document_id': 'xnbl0037',
#  'ucsf_document_page_no': '1',
#  'answers': ['1/8/93'],
#  'data_split': 'train'}

# %%
data['dataset_name']
# Out:
# 'SP-DocVQA'

# %%
data.keys()
# Out:
# dict_keys(['dataset_name', 'dataset_version', 'dataset_split', 'data'])

# %%
data['data'][0]['image']
# Out:
# 'documents/xnbl0037_1.png'

# %%
data['data'][0]['image']
# Out:
# 'documents/rnbx0223_193.png'

# %%
import pandas as pd

# %%
x = pd
